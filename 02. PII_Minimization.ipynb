# %%
df_source = spark.read.table("pii_demo.pii_source.customers")

# %%
pii_minimized = df_source.select("customer_id", "city", "country")

# %%
pii_minimized.write.mode("overwrite").saveAsTable("pii_demo.pii_target.customers_minimized")

# %%
# %sql
SELECT * FROM pii_demo.pii_target.customers_minimized;
